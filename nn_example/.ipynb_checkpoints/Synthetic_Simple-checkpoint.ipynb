# %%
import pandas as pd
import numpy as np
import scipy as sp

from sklearn.ensemble import BaggingRegressor



import corner
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Functions to Relate Conditions to Samples
#
# **Environment**
# - A
# - B
# - C
#
# **Geochem**
# - pA
# - pB
# - pC
#
# Basically, we want to map pA, pB and pC to independent input variables A, B and C in this problem.
#
# The relationships between the observations (pA, pB and pC) and the independent variables are:

# %%
def fpA(A, B, C):
    return 1 #- 4 * B**(C * 0.1)

def fpB(A, B, C):
    return A + 8*B

def fpC(A, B, C):
    return C * 100

# %% [markdown]
# ## Generate Synthetic Data

# %%
# synthetic environment
N = int(1e4)

A = np.random.uniform(1, 10, N)
B = np.random.uniform(1, 10, N)
C = np.random.uniform(1, 10, N)

# synthetic data
pA = fpA(A, B, C)
pB = fpB(A, B, C)
pC = fpC(A, B, C)

# combine datasets
env = pd.DataFrame({'A': A,
                    'B': B,
                    'C': C})
foram = pd.DataFrame({'pA': pA,
                      'pB': pB,
                      'pC': pC})

# add noise to foram
# foram *= np.random.normal(1, 0.0001, foram.shape)

# %% [markdown]
# # Plotting independent variables against correlated (observed) parameters

# %%
tt = 1
for i in env.columns:
    for j in foram.columns:

        plt.subplot(3,3,tt)
        plt.scatter(env[i],foram[j],s=0.1,alpha=0.1)
        plt.xlabel(i)
        plt.ylabel(j)
        tt = tt +1
        
plt.tight_layout()

# %% [markdown]
# ## Data Wrangling

# %%
from sklearn import model_selection
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor

# %% [markdown]
# # Scaling and test/train split

# %%
# create scalers and apply to data
env_scaler = StandardScaler()
foram_scaler = StandardScaler()

foram_scaler.fit(foram)
env_scaler.fit(env)

tenv = env_scaler.transform(env)
tforam = foram_scaler.transform(foram)

# %%
# split into test/training
tenv_train, tenv_test, tforam_train, tforam_test = model_selection.train_test_split(tenv, tforam, test_size=0.3)

# %% [markdown]
# ## Neural network regressor
#
# Using the MLPRegressor function

# %%
nn = MLPRegressor((100, 10, 10),solver='lbfgs',activation='tanh')
nn.fit(tforam_train, tenv_train)
# Out:
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 10, 10), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='lbfgs', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
train_prediction = env_scaler.inverse_transform(nn.predict(tforam_train))

# %%
test_prediction = env_scaler.inverse_transform(nn.predict(tforam_test))

# %%
def limcalc(x, pad=0.05): # simple function for plots
    rn = np.ptp(x)
    return np.nanmin(x) - rn * pad, np.nanmax(x) + rn * pad

# %%
fig, axs = plt.subplots(1, 3, figsize=[8, 3])

meas = env_scaler.inverse_transform(tenv_train)
pred = train_prediction

for i, (p, ax) in enumerate(zip(env.columns, axs.flat)):
    ax.set_xlabel(p)
    
    x = meas[:, i]
    y = pred[:, i]
    
    ax.scatter(x, y, alpha=0.2, s=5)
    
    mlim = limcalc(x)
    
    ax.set_xlim(mlim)
    ax.set_ylim(mlim)
    ax.plot(mlim, mlim, c='k')
    
fig.tight_layout()

# %% [markdown]
# A and B are correlated in their functions, and this is now visible in the predictions of the network...
#
# Interestingly, the neural net predictions are affected by this correlation.
#
# We can plot A and B colored with C values to get a feeling of that...

# %%
plt.figure()

# norm is a class which, when called, can normalize data into the
# [0.0, 1.0] interval.
norm = matplotlib.colors.Normalize(
    vmin=np.min(pred[:,2]),
    vmax=np.max(pred[:,2]))

# choose a colormap
c_m = matplotlib.cm.cool

# create a ScalarMappable and initialize a data structure
s_m = matplotlib.cm.ScalarMappable(cmap=c_m, norm=norm)
s_m.set_array([])


plt.scatter(pred[:,0],pred[:,1],s = 0.1,c=s_m.to_rgba(pred[:,2]))
plt.xlabel('A',fontsize=12)
plt.ylabel('B',fontsize=12)

# having plotted the 11 curves we plot the colorbar, using again our
# ScalarMappable
c_bar = plt.colorbar(s_m)
c_bar.set_label(r"C")

plt.savefig('neuralnet_art.png')

# %% [markdown]
# ## Support Vector Machine
#
# Trying the regression with a SVM.
#
# We did not even tune the hyperparams in this simple example, which is only there to compare how the SVM roughly performs compare to neural nets...

# %%
from sklearn import svm
from sklearn.multioutput import MultiOutputRegressor

# %%
sv = svm.SVR()

# %%
mo = MultiOutputRegressor(sv)

# %%
mo.fit(tforam_train, tenv_train)
# Out:
# MultiOutputRegressor(estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False),
#            n_jobs=1)

# %%
pred = mo.predict(tforam_train)

# %%
train_prediction = env_scaler.inverse_transform(pred)

# %%
fig, axs = plt.subplots(1, 3, figsize=[8, 3])

meas = env_scaler.inverse_transform(tenv_train)
pred = train_prediction

for i, (p, ax) in enumerate(zip(env.columns, axs.flat)):
    ax.set_xlabel(p)
    
    x = meas[:, i]
    y = pred[:, i]
    
    ax.scatter(x, y, alpha=0.2, s=5)
    
    mlim = limcalc(x)
    
    ax.set_xlim(mlim)
    ax.set_ylim(mlim)
    ax.plot(mlim, mlim, c='k')
    
fig.tight_layout()

# %%
plt.figure()

# norm is a class which, when called, can normalize data into the
# [0.0, 1.0] interval.
norm = matplotlib.colors.Normalize(
    vmin=np.min(pred[:,2]),
    vmax=np.max(pred[:,2]))

# choose a colormap
c_m = matplotlib.cm.cool

# create a ScalarMappable and initialize a data structure
s_m = matplotlib.cm.ScalarMappable(cmap=c_m, norm=norm)
s_m.set_array([])


plt.scatter(pred[:,0],pred[:,1],s = 0.1,c=s_m.to_rgba(pred[:,2]))
plt.xlabel('A',fontsize=12)
plt.ylabel('B',fontsize=12)

# having plotted the 11 curves we plot the colorbar, using again our
# ScalarMappable
c_bar = plt.colorbar(s_m)
c_bar.set_label(r"C")

plt.savefig('svm_art.png')

# %% [markdown]
# The correlation is thus also visible in the SVM results, and seems intrisic to the mathematical definition of the problem.
#
# ## Trying with Kernel Ridge

# %%
from sklearn.kernel_ridge import KernelRidge

# %%
kr = KernelRidge(kernel='rbf')

# %%
kr.fit(tforam_train, tenv_train)
# Out:
# KernelRidge(alpha=1, coef0=1, degree=3, gamma=None, kernel='rbf',
#       kernel_params=None)

# %%
pred = kr.predict(tforam_train)
train_prediction = env_scaler.inverse_transform(pred)

# %%
fig, axs = plt.subplots(1, 3, figsize=[8, 3])

meas = env_scaler.inverse_transform(tenv_train)
pred = train_prediction

for i, (p, ax) in enumerate(zip(env.columns, axs.flat)):
    ax.set_xlabel(p)
    
    x = meas[:, i]
    y = pred[:, i]
    
    ax.scatter(x, y, alpha=0.2, s=5)
    
    mlim = limcalc(x)
    
    ax.set_xlim(mlim)
    ax.set_ylim(mlim)
    ax.plot(mlim, mlim, c='k')
    
fig.tight_layout()

# %%
plt.figure()

# norm is a class which, when called, can normalize data into the
# [0.0, 1.0] interval.
norm = matplotlib.colors.Normalize(
    vmin=np.min(pred[:,2]),
    vmax=np.max(pred[:,2]))

# choose a colormap
c_m = matplotlib.cm.cool

# create a ScalarMappable and initialize a data structure
s_m = matplotlib.cm.ScalarMappable(cmap=c_m, norm=norm)
s_m.set_array([])


plt.scatter(pred[:,0],pred[:,1],s = 0.1,c=s_m.to_rgba(pred[:,2]))
plt.xlabel('A',fontsize=12)
plt.ylabel('B',fontsize=12)

# having plotted the 11 curves we plot the colorbar, using again our
# ScalarMappable
c_bar = plt.colorbar(s_m)
c_bar.set_label(r"C")

plt.savefig('kr_art.png')

# %% [markdown]
# # Solution?
#
# Maybe train 3 neural networks to separately predict A, B and C?

# %%
nn1 = MLPRegressor((10,),solver='adam',activation='relu')
nn1.fit(tforam_train, tenv_train[:,0])

nn2 = MLPRegressor((10,),solver='adam',activation='relu')
nn2.fit(tforam_train, tenv_train[:,1])

nn3 = MLPRegressor((10,),solver='adam',activation='relu')
nn3.fit(tforam_train, tenv_train[:,2])
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
train_prediction = env_scaler.inverse_transform(np.transpose(np.vstack((nn1.predict(tforam_train),nn2.predict(tforam_train),nn3.predict(tforam_train)))))
test_prediction = env_scaler.inverse_transform(np.transpose(np.vstack((nn1.predict(tforam_test),nn2.predict(tforam_test),nn3.predict(tforam_test)))))

# %%
fig, axs = plt.subplots(1, 3, figsize=[8, 3])

meas = env_scaler.inverse_transform(tenv_train)
pred = train_prediction

for i, (p, ax) in enumerate(zip(env.columns, axs.flat)):
    ax.set_xlabel(p)
    
    x = meas[:, i]
    y = pred[:, i]
    
    ax.scatter(x, y, alpha=0.2, s=5)
    
    mlim = limcalc(x)
    
    ax.set_xlim(mlim)
    ax.set_ylim(mlim)
    ax.plot(mlim, mlim, c='k')
    
fig.tight_layout()

# %%
plt.figure()

# norm is a class which, when called, can normalize data into the
# [0.0, 1.0] interval.
norm = matplotlib.colors.Normalize(
    vmin=np.min(pred[:,2]),
    vmax=np.max(pred[:,2]))

# choose a colormap
c_m = matplotlib.cm.cool

# create a ScalarMappable and initialize a data structure
s_m = matplotlib.cm.ScalarMappable(cmap=c_m, norm=norm)
s_m.set_array([])


plt.scatter(pred[:,0],pred[:,1],s = 0.1,c=s_m.to_rgba(pred[:,2]))
plt.xlabel('A',fontsize=12)
plt.ylabel('B',fontsize=12)

# having plotted the 11 curves we plot the colorbar, using again our
# ScalarMappable
c_bar = plt.colorbar(s_m)
c_bar.set_label(r"C")

plt.savefig('nn_composite_art.png')

# %% [markdown]
# Does not really work... So such kind of problem requires a more complex approach to be able to provide a robust solution...
#
# In all case, this example is interesting as it shows that if you see weird stuffs going on in your outputs, this can reflect some complexity in your model that the machine learning technics can not map easily...

# %% [markdown]
# ## Extra code: Keras trial
#
# if you have Keras you can run the following...

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-a3a5d448be55> in <module>()
# ----> 1 import keras
#       2 from keras.models import Sequential
#       3 from keras.layers import Dense
#       4 from keras.wrappers.scikit_learn import KerasRegressor
#       5 from sklearn.model_selection import cross_val_score
#
# ModuleNotFoundError: No module named 'keras'

# %%
# define the model
def larger_model():
    # create model
    model = Sequential()
    model.add(Dense(20, input_dim=3, kernel_initializer='normal', activation='relu'))
    model.add(Dense(20, kernel_initializer='normal', activation='relu'))
    model.add(Dense(20, kernel_initializer='normal', activation='relu'))
    model.add(Dense(3, kernel_initializer='normal'))  # must be 3 because 3 in output array
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# evaluate model with standardized dataset
estimator = KerasRegressor(build_fn=larger_model, epochs=100, batch_size=200, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-695a593c109c> in <module>()
#       1 # evaluate model with standardized dataset
# ----> 2 estimator = KerasRegressor(build_fn=larger_model, epochs=100, batch_size=200, verbose=0)
#
# NameError: name 'KerasRegressor' is not defined

# %%
# K-fold validation... clever stuff.
# kfold = KFold(n_splits=5, random_state=42)
# results = cross_val_score(estimator, tforam_train, tenv_train, cv=kfold)
# print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))

# %%
estimator.fit(tforam_train, tenv_train)

# %%
pred = estimator.predict(tforam_train)

# %%
fig, axs = plt.subplots(1, 3, figsize=[8, 3])

meas = env_scaler.inverse_transform(tenv_train)
pred = env_scaler.inverse_transform(pred)

for i, (p, ax) in enumerate(zip(env.columns, axs.flat)):
    ax.set_xlabel(p)
    
    x = meas[:, i]
    y = pred[:, i]
    
    ax.scatter(x, y, alpha=0.2, s=5)
    
    mlim = limcalc(x)
    
    ax.set_xlim(mlim)
    ax.set_ylim(mlim)
    ax.plot(mlim, mlim, c='k')
    
fig.tight_layout()
